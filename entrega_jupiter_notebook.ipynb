# %% [markdown]
# Ejercicios para entregar. MARKDOWN

# %% [markdown]
# # Ejercicio 1: Cabeceras
# # Ciencia de Datos
# ## Introducción
# ### Herramientas

# %% [markdown]
# # Ejercicio 2: Estilos de texto
# **Markdown**
# *Jupyter*
# ***Python***

# %% [markdown]
# # Ejercicio 3: Resaltados y HTML
# <mark>resaltado</mark>
# <font color="blue"> color </font>

# %% [markdown]
# # Ejercicio 4: Citas
# >La Ciencia de Datos es el petróleo del siglo XXI.
# >>La Ciencia de Datos es el petróleo del siglo XXI.

# %% [markdown]
# # Ejercicio 5: Combinando todo
# ## Curso de Markdown
# Es  muy **importante** saber manejar el markdown en el jupiter notebook.
# >Aprender es crecer
#
# <span style="background-color: green; font-style: italic; color: white;">ejemplo

# %% [markdown]
# # Ejercicio 6: Listas
#
# * Manzanas
# - Plátanos
# + Uvas

# %% [markdown]
# 1. Arbol binario
# 2. Random Forest
# 3. Regresión Logística

# %% [markdown]
# # Ejercicio 7: Listas Anidadas
#
# #### Frutas y verduras
# 1. Frutas:
#   1.1. citricos
#   * naranja
#   + pomelo
#   - limon
#   1.2. Frutos
#   * platano
#   + manzana
#   - frambuesas
#
# 2. Verduras:
#   2.1. Hoja
#   * berza
#   + rucula
#   - Lechuga
#   2.2. Fruto
#   * calabacin
#   + cebolla
#   - Tomate

# %% [markdown]
# # Ejercicio 8: Enlaces e Imágenes
#
# [Por aquí se cruzan puentes](www.thebridge.com).
#
# ![logo-1933884_1280.webp](attachment:d0e0ac46-6bf3-4831-b232-b1cf8b9ea9da.webp)

# %% [markdown]
# # Ejercicio 9: Líneas Horizontales y Bloques de Código

# %% [markdown]
# ***

# %%
print("Hola Mundo")

# %% [markdown]
# ---
